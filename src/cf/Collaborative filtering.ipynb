# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from surprise import Reader, Dataset, SVD, evaluate  # special library for reco systems
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm # Track progress

# %%
# Normal train and test set (filtered and split)
df_train= pd.read_csv('../../data/generated/inter_train.csv')
df_train = df_train.dropna()
df_test= pd.read_csv('../../data/generated/inter_test.csv') 
# df_test = df_test.dropna()


# Read as matrix format of train and test set
X_train = pd.read_csv('../../data/generated/inter_test.csv').pivot_table(
                            index='u', columns='i', values='rating', dropna=False)
X_test = pd.read_csv('../../data/generated/inter_train.csv').pivot_table(
                            index='u', columns='i', values='rating', dropna=False)


# Full data - no train/test split 
full_data = pd.read_csv('../../data/generated/full_data_filtered.csv')
full_data_matrix = full_data.pivot_table(index='u', columns='i', values='rating', dropna=False)


# Create a dataframe giving the recipe's name along with its id 'i'
names = pd.read_csv('../../data/generated/names.csv')
names.columns=['i','name']
names = names.set_index('i') # set 'i' as index, useful later.

# %% [markdown]
# ## CF

# %%
# User we consider for recommendation
user_index = 0

# Number of similar users for recommendation
n_recommendation = 25

# Plot top n recommendations
n_plot = 10

# Fill in missing values with mean value 
# train = X_train.T.fillna(X_train.mean(axis=1)).T

# Fill in missing values with -1 and add 1 to each rating (want NaN to 0)
train = X_train.fillna(-1)
train = train.add(1)
train2 = train.T  # make us save a few seconds in similarity computation

# %%
# Compute similarity metric (only for user 0 and all other users)
import time
start_time = time.time()

l = train.T.columns.tolist()
mean_user_x = X_train.iloc[user_index,:].mean()
similarity = []

for i in range(len(l)):
    m = X_train.iloc[i,:].mean()
    sim = np.sum( (train2[l[i]] * train.iloc[user_index,:]) / ((m * mean_user_x) * (abs(train2[l[i]] - train.iloc[user_index,:]) +1 )) )
    similarity.append(sim)  

# Watch time it takes
end_time = time.time()
total_time = end_time - start_time
print("Time: ", total_time)

# Remove similarity of user with itself 
similarity.remove(similarity[user_index])
# Out:
# Time:  51.99180817604065

# %%
# Sort similar users by index
similar_user_index = np.argsort(similarity)[::-1]

# Sort similar users by score
similar_user_score = np.sort(similarity)[::-1]

# %%
# Store unrated recipes (for the user considered)
unrated_recipes = X_train.iloc[user_index][X_train.iloc[user_index].isna()].index 

# Weight ratings of the top n most similar users via similarity score and compute the mean predicted rating for each recipe
# Score associated with each recipe indicates how likely user X is to like this recipe wrt to others. It is not a predicted rating. 
mean_recipe_recommendations = (train.iloc[similar_user_index[:n_recommendation]].T * similar_user_score[:n_recommendation]).T.mean(axis=0)

# Filter already rated recipes for user regarded and sort results
# Also join the corresponding name of each recipe 
best_recipe_recommendations = mean_recipe_recommendations[unrated_recipes].sort_values(ascending=False).to_frame().join(names)

# Print 10 recommendations 
best_recipe_recommendations[:n_plot]
# Out:
#                0                                               name
# i
# 160154  0.883578                                    lemon baked cod
# 57030   0.816411                                 spicy potato bumps
# 33680   0.700062                                      pesto chicken
# 118670  0.667233         grilled chicken breast with barbecue glaze
# 97450   0.646995                roasted parmesan garlic cauliflower
# 44474   0.454737  pacific rim chicken burgers with ginger mayonn...
# 137554  0.454737                           chicken bites with spice
# 14789   0.454737                               amanda s thai peanut
# 164837  0.454737                    sweet salsa dump chicken   oamc
# 177367  0.454737                               cashew chicken curry

# %%
# We want to estimate the rating a user would give to these recipes
# Create trace
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
trace = go.Bar(x = best_recipe_recommendations.iloc[:n_plot, 0],
               text = best_recipe_recommendations['name'],
               textposition = 'inside',
               textfont = dict(color = '#000000'),
               orientation = 'h',
               y = list(range(1, n_plot+1)),
               marker = dict(color = '#db0000'))
# Create layout
layout = dict(title = 'Ranking Of Top {} Recommended Recipes For A User Based On Similarity'.format(n_plot),
              xaxis = dict(title = 'Recommendation-Rating',
                           range = (0, best_recipe_recommendations.iloc[0,0])),
              yaxis = dict(title = 'Recipe'))
# Create plot
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="87ee54e0-aa20-4d98-8d0b-f34ea470c581" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87ee54e0-aa20-4d98-8d0b-f34ea470c581")) {
#                     Plotly.newPlot(
#                         '87ee54e0-aa20-4d98-8d0b-f34ea470c581',
#                         [{"marker": {"color": "#db0000"}, "orientation": "h", "text": ["lemon baked cod", "spicy potato bumps", "pesto chicken", "grilled chicken breast with barbecue glaze", "roasted parmesan garlic cauliflower", "pacific rim chicken burgers with ginger mayonnaise", "chicken bites with spice", "amanda s thai peanut", "sweet salsa dump chicken   oamc", "cashew chicken curry", "fried rice for 2", "herbed lemon chicken in a crock pot   slow cooker", "honey lemon chicken", "weight watchers chicken and cheese casserole", "crumpets with cheese   bacon", "wallumbilla crustless quiche", "ham and egg salad with crackers", "kato s cornbread", "beef stuffed potatoes", "opal s pumpkin pie", "creamy quiche lorraine   wow  em", "best ever summer strawberry spinach salad", "moroccan chickpeas and sweet potatoes", "pad thai with chicken and shrimp", "bacardi rum cake", "the original cabbage soup diet", "italian dressing seasoning dry mix", "dry rub pork ribs", "baked turkey tenderloin", "sauteed baby spinach and garlic", "easy garlic chicken", "slow cook down home pork chops and gravy", "melt in your mouth blueberry muffins", "biggest loser creamy tuna lemon and garlic pasta", "parmesan zucchini", "very quick butter chickpeas  vegetarian butter chicken", "best ever banana cake with cream cheese frosting", "spanish grilled chicken breasts", "chicken cream cheese enchiladas", "mexican grilled chicken", "original indian naan bread", "tarragon lime chicken breast", "robyn s fish stick tacos", "beans and greens", "fake rotisserie chicken", "strawberry cheesecake trifle", "garlic parmesan chicken wings", "pioneer woman chicken spaghetti", "cooked chicken for recipes   barefoot contessa style", "linda s hawaiian barbecue sauce for barbecue chicken and ribs", "pork steak chop sauce", "chow gai laan  jade green broccoli", "homemade  suddenly salad", "chinese style chicken thighs", "treebeard s red beans  and rice", "asian pasta salad", "amanda s cheese pound cake", "baked buffalo chicken breasts", "crock pot stuffed steak", "baked pork chops and apples", "v s do ahead slow cooker mashed potatoes", "paula deen s best ham salad sandwich", "my family s favorite sloppy joes  pizza joes", "philly cheesesteak casserole  low carb", "blueberry crumb pie", "crispy eggplant", "pepsi pork roast", "philly cheesesteak pizza", "herb coated cod", "italian creamy noodles", "hearty chicken   noodle casserole", "real simple bean and bacon soup", "chewy macaroons", "tater tot cups with cheese and eggs", "pumpkin seeds", "perch fillets", "bacon wrapped smoked gouda stuffed chicken breasts", "payday bars", "best blueberry crisp", "5 ingredient baked potato skins", "peanut butter cup cookies  tarts", "garlic roasted asparagus with parmesan", "allrighty then scrambled eggs   paula deen", "almost apple pie", "spicy baked sweet potato  fries", "spiced sweet potato fries", "kittencal s parmesan garlic bread or garlic toast", "the best apple pie muffins ever", "sirloin soup italiano", "easy grilled cajun chicken", "low carb crock pot pizza soup", "slow cooked baked apples", "kittencal s italian melt in your mouth meatballs", "fresh blueberry cobbler", "simple italian baked chicken", "freakin  good guacamole", "irish rosie s irish soda bread", "chipotle roast for tacos   sandwiches", "pammy s crock pot chicken breast and gravy", "thick and creamy new england clam chowder", "thai chicken fried rice with basil   kao pad krapao", "balsamic tomato basil pasta", "javanese roasted salmon and wilted spinach", "honey lemon chicken thighs", "mediterranean scampi", "mrs  geraldine s ground beef casserole", "tomato crowned cod", "make ahead bisquick sausage ball appetizers", "chipotle oven fried chicken", "perfect rump roast", "flounder stuffed with shrimp and crabmeat", "benihana japanese fried rice", "daddy s kettle corn", "chocolate cupcakes with chocolate frosting", "chicken agrodolce  an italian sweet and sour chicken", "sherry cherry tomatoes", "pineapple   mandarin  ...

# %%
# Let's see what would be the predicted rating of each recommended recipe. 
# The rating is computed as the average of the most similar users' ratings, weighted by their similarity score. 

prediction = []
brr = best_recipe_recommendations[:n_plot]
list_brr = brr.index.values.tolist()

# Regard all recipes 
for recipe_id in list_brr:
    
    # Compute predicted score (weighted average of similar user score)
    a = X_train.iloc[similar_user_index[:n_recommendation]][recipe_id].notnull()
    a = pd.DataFrame(a.ravel()) 
    score = (X_train.iloc[similar_user_index[a[a[0]==True].index.tolist()]][recipe_id] * similar_user_score[a[a[0]==True].index.tolist()]).sum() / similar_user_score[a[a[0]==True].index.tolist()].sum()
    prediction.append([recipe_id, score])
    
# Create prediction DataFrame - predict ratings of the recipes in test sets (for each user)
df_pred = pd.DataFrame(prediction, columns=['i', 'Prediction']).set_index(['i'])

# %%
# Create trace
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
trace = go.Bar(x = df_pred.iloc[:,0],
               text = best_recipe_recommendations['name'],
               textposition = 'inside',
               textfont = dict(color = '#000000'),
               orientation = 'h',
               y = list(range(1, n_plot+1)),
               marker = dict(color = '#db0000'))
# Create layout
layout = dict(title = 'Ranking Of Top {} Recommended Recipes For A User Based On Similarity'.format(n_plot),
              xaxis = dict(title = 'Recommendation-Rating',
                           range = (0, 5)),
              yaxis = dict(title = 'Recipe'))
# Create plot
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="6c74bb1f-f226-4e1c-b01d-7b69e75e5527" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6c74bb1f-f226-4e1c-b01d-7b69e75e5527")) {
#                     Plotly.newPlot(
#                         '6c74bb1f-f226-4e1c-b01d-7b69e75e5527',
#                         [{"marker": {"color": "#db0000"}, "orientation": "h", "text": ["lemon baked cod", "spicy potato bumps", "pesto chicken", "grilled chicken breast with barbecue glaze", "roasted parmesan garlic cauliflower", "pacific rim chicken burgers with ginger mayonnaise", "chicken bites with spice", "amanda s thai peanut", "sweet salsa dump chicken   oamc", "cashew chicken curry", "fried rice for 2", "herbed lemon chicken in a crock pot   slow cooker", "honey lemon chicken", "weight watchers chicken and cheese casserole", "crumpets with cheese   bacon", "wallumbilla crustless quiche", "ham and egg salad with crackers", "kato s cornbread", "beef stuffed potatoes", "opal s pumpkin pie", "creamy quiche lorraine   wow  em", "best ever summer strawberry spinach salad", "moroccan chickpeas and sweet potatoes", "pad thai with chicken and shrimp", "bacardi rum cake", "the original cabbage soup diet", "italian dressing seasoning dry mix", "dry rub pork ribs", "baked turkey tenderloin", "sauteed baby spinach and garlic", "easy garlic chicken", "slow cook down home pork chops and gravy", "melt in your mouth blueberry muffins", "biggest loser creamy tuna lemon and garlic pasta", "parmesan zucchini", "very quick butter chickpeas  vegetarian butter chicken", "best ever banana cake with cream cheese frosting", "spanish grilled chicken breasts", "chicken cream cheese enchiladas", "mexican grilled chicken", "original indian naan bread", "tarragon lime chicken breast", "robyn s fish stick tacos", "beans and greens", "fake rotisserie chicken", "strawberry cheesecake trifle", "garlic parmesan chicken wings", "pioneer woman chicken spaghetti", "cooked chicken for recipes   barefoot contessa style", "linda s hawaiian barbecue sauce for barbecue chicken and ribs", "pork steak chop sauce", "chow gai laan  jade green broccoli", "homemade  suddenly salad", "chinese style chicken thighs", "treebeard s red beans  and rice", "asian pasta salad", "amanda s cheese pound cake", "baked buffalo chicken breasts", "crock pot stuffed steak", "baked pork chops and apples", "v s do ahead slow cooker mashed potatoes", "paula deen s best ham salad sandwich", "my family s favorite sloppy joes  pizza joes", "philly cheesesteak casserole  low carb", "blueberry crumb pie", "crispy eggplant", "pepsi pork roast", "philly cheesesteak pizza", "herb coated cod", "italian creamy noodles", "hearty chicken   noodle casserole", "real simple bean and bacon soup", "chewy macaroons", "tater tot cups with cheese and eggs", "pumpkin seeds", "perch fillets", "bacon wrapped smoked gouda stuffed chicken breasts", "payday bars", "best blueberry crisp", "5 ingredient baked potato skins", "peanut butter cup cookies  tarts", "garlic roasted asparagus with parmesan", "allrighty then scrambled eggs   paula deen", "almost apple pie", "spicy baked sweet potato  fries", "spiced sweet potato fries", "kittencal s parmesan garlic bread or garlic toast", "the best apple pie muffins ever", "sirloin soup italiano", "easy grilled cajun chicken", "low carb crock pot pizza soup", "slow cooked baked apples", "kittencal s italian melt in your mouth meatballs", "fresh blueberry cobbler", "simple italian baked chicken", "freakin  good guacamole", "irish rosie s irish soda bread", "chipotle roast for tacos   sandwiches", "pammy s crock pot chicken breast and gravy", "thick and creamy new england clam chowder", "thai chicken fried rice with basil   kao pad krapao", "balsamic tomato basil pasta", "javanese roasted salmon and wilted spinach", "honey lemon chicken thighs", "mediterranean scampi", "mrs  geraldine s ground beef casserole", "tomato crowned cod", "make ahead bisquick sausage ball appetizers", "chipotle oven fried chicken", "perfect rump roast", "flounder stuffed with shrimp and crabmeat", "benihana japanese fried rice", "daddy s kettle corn", "chocolate cupcakes with chocolate frosting", "chicken agrodolce  an italian sweet and sour chicken", "sherry cherry tomatoes", "pineapple   mandarin  ...

# %%
# Let's just check what would happen if we don't weight ratings using similarity score - and take the mean of only exisiting ratings 
mean_reci_reco = (X_train.iloc[similar_user_index[:n_recommendation]].T).T.mean(axis=0)
best_rec_reco= mean_reci_reco[unrated_recipes].sort_values(ascending=False).to_frame().join(names)
best_rec_reco[:n_plot]
# Recipes with only one rating, but a 5.0 are favoured with this technique. Also, too many recipes could be proposed (score of 5)
# Out:
#           0                                               name
# i
# 177367  5.0                               cashew chicken curry
# 82309   5.0                              sirloin soup italiano
# 92110   5.0                tater tot cups with cheese and eggs
# 91525   5.0  kittencal s rich homemade beef stock  crock po...
# 90467   5.0         pammy s crock pot chicken breast and gravy
# 85481   5.0               chocolate chip mexican wedding cakes
# 85206   5.0                                   almost apple pie
# 29746   5.0  roasted cauliflower   16 roasted cloves of garlic
# 31418   5.0                         easy grilled cajun chicken
# 82257   5.0             the best peanut butter oatmeal cookies

# %% [markdown]
# ## Test accuracy of predictions on test set

# %%
# Look at our predictions for test set recipes, rated by our targeted user. 
# Predictions are a weighted average of simimar user ratings

# Create user-id mapping
user_id = l[user_index]
# print('for user'+str(user_id))
# user_id_mapping = {id:i for i, id in enumerate(train.index)}

prediction = []

# Regard only recipes that are present in the test set - careful there are NaN values
for recipe_id in df_test[df_test['u']==user_id]['i'].values:
    
    # Compute predicted score (weighted average of similar user score)
    a = X_test.iloc[similar_user_index[:n_recommendation]][recipe_id].notnull()
    a = pd.DataFrame(a.ravel()) 
    score = (X_test.iloc[similar_user_index[a[a[0]==True].index.tolist()]][recipe_id] * similar_user_score[a[a[0]==True].index.tolist()]).sum() / similar_user_score[a[a[0]==True].index.tolist()].sum()
    prediction.append([user_id, recipe_id, score])
# Out:
# /Users/alexandreduval/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
# Create prediction DataFrame - predict ratings of the recipes in test sets (for each user)
df_pred = pd.DataFrame(prediction, columns=['u', 'i', 'Prediction']).set_index(['i'])

# Add rating of each recipe for this user to the prediction dataframe 
df_i = pd.DataFrame(df_test[df_test['u']==user_id]['i'])
df_r = pd.DataFrame(df_test[df_test['u']==user_id]['rating'])
df_test_user = df_i.join(df_r).set_index(['i'])
df_pred = df_pred.join(df_test_user )

# Drop NaN values (observations without ratings for each user)
df_pred = df_pred.dropna()

# %%
# Get labels and predictions
y_true = df_pred['rating'].values
y_pred = df_pred['Prediction'].values

# Compute RMSE
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_true=y_true, y_pred=y_pred))

# %% [markdown]
# ## REDO same as above but with the whole dataset (no train/test split)
# This yields more accurate predicted ratings but withdraw the possibility to test our findings.

# %%
# Simply use and rerun code above 
X_train = full_data_matrix 
df_train = full_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-f34fefae0be7> in <module>
#       1 # Simply needs to combine the train and test dataset
#       2 #df_full_data = pd.concat([pd.read_csv(f'{DATA_FOLDER}interactions_{typ}.csv') for typ in ['train', 'validation', 'test']])
# ----> 3 df_full_data= pd.merge(X_train, X_test, how='inner')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      46                          copy=copy, indicator=indicator,
#      47                          validate=validate)
# ---> 48     return op.get_result()
#      49
#      50
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     544                 self.left, self.right)
#     545
# --> 546         join_index, left_indexer, right_indexer = self._get_join_info()
#     547
#     548         ldata, rdata = self.left._data, self.right._data
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_info(self)
#     754         else:
#     755             (left_indexer,
# --> 756              right_indexer) = self._get_join_indexers()
#     757
#     758             if self.right_index:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_indexers(self)
#     733                                   self.right_join_keys,
#     734                                   sort=self.sort,
# --> 735                                   how=self.how)
#     736
#     737     def _get_join_info(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1131
#    1132     # get flat i8 keys from label lists
# -> 1133     lkey, rkey = _get_join_keys(llab, rlab, shape, sort)
#    1134
#    1135     # factorize keys to a dense i8 space
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1726     shape = [count] + shape[nlev:]
#    1727
# -> 1728     return _get_join_keys(llab, rlab, shape, sort)
#    1729
#    1730
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_join_keys(llab, rlab, shape, sort)
#    1703     # how many levels can be done without overflow
#    1704     pred = lambda i: not is_int64_overflow_possible(shape[:i])
# -> 1705     nlev = next(filter(pred, range(len(shape), 0, -1)))
#    1706
#    1707     # get keys for the first `nlev` levels
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in <lambda>(i)
#    1702
#    1703     # how many levels can be done without overflow
# -> 1704     pred = lambda i: not is_int64_overflow_possible(shape[:i])
#    1705     nlev = next(filter(pred, range(len(shape), 0, -1)))
#    1706
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/sorting.py in is_int64_overflow_possible(shape)
#     125     the_prod = long(1)
#     126     for x in shape:
# --> 127         the_prod *= long(x)
#     128
#     129     return the_prod >= _INT64_MAX
#
# KeyboardInterrupt:

# %%
"""
# Sparse matrix 
# Read doc, there are several types 
import scipy.sparse as sp
from scipy.sparse import csr_matrix, find 
train_s = csr_matrix (train)
test = X_test.fillna(-1)
test = test.add(1)
test_s = csr_matrix(test)
df_full_data = sp.vstack((train_s, test_s))
"""

# %% [markdown]
# ## Compute this similarity measure for all users - use sparse matrix

# %%
"""

# Compute mean rating of each user
l = train.T.columns.tolist() # store all user id
    
m =[]
for i in range(len(l)):
    m.append(X_train.iloc[i,:].mean())


# Compute similarity metric (only for user 0 and all other users)
# Find a way to use mean above (speed up computations)

l = train.columns.tolist()
dico={}
for j in tqdm(range(X_train.shape[1])): 

    mean_user_x = X_train.iloc[:,j].mean()
    sim = []
    for i in range(len(l)):
        m = X_train.iloc[:,i].mean()
        similarity = np.sum( (train[l[i]] * train.iloc[:,j]) / ((m * mean_user_x) * (abs(train[l[i]] - train.iloc[:,j])+1 )) )
        sim.append(similarity)  
    dico[j]= sim
    

# Convert dico into dataframe 
# pd.DataFrame.from_dict(data) 

# Maybe need to delete similarity with respect to itself
# Only 10 non neg values. They are quite different, which is pretty nice. 

"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-852b26fabdd1> in <module>
#       9     for i in range(len(l)):
#      10         m = X_train.iloc[:,i].mean()
# ---> 11         similarity = np.sum( (train[l[i]] * train.iloc[:,j]) / ((m * mean_user_x) * (abs(train[l[i]] - train.iloc[:,j])+1 )) )
#      12         sim.append(similarity)
#      13     dico[j]= sim
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2143         self._has_valid_tuple(tup)
#    2144         try:
# -> 2145             return self._getitem_lowerdim(tup)
#    2146         except IndexingError:
#    2147             pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2230             self._validate_integer(key, axis)
#    2231
# -> 2232             return self._get_loc(key, axis=axis)
#    2233
#    2234     def _convert_to_indexer(self, obj, axis=None, is_setter=False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_loc(self, key, axis)
#     144         if axis is None:
#     145             axis = self.axis
# --> 146         return self.obj._ixs(key, axis=axis)
#     147
#     148     def _slice(self, obj, axis=None, kind=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    2880                 # a 0-len ndarray. This is effectively catching
#    2881                 # a numpy error (as numpy should really raise)
# -> 2882                 values = self._data.iget(i)
#    2883
#    2884                 if index_len and not len(values):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in iget(self, i, fastpath)
#     977                                          placement=slice(0, len(values)),
#     978                                          ndim=1)],
# --> 979             self.axes[1])
#     980
#     981     def delete(self, item):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1468
#    1469                 # provide consolidation to the interleaved_dtype
# -> 1470                 if len(block) > 1:
#    1471                     dtype = _interleaved_dtype(block)
#    1472                     block = [b.astype(dtype) for b in block]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Extension of CF to all users with cosine similarity

# %%
# Redefine train
train = X_train.T.fillna(-1).T
train = train.add(1)

# Compute similarity between all users
similarity = cosine_similarity(train.values)

# Remove self-similarity from similarity-matrix
similarity -= np.eye(similarity.shape[0])

# Sort similar users by index
similar_user_index = np.argsort(similarity[user_index])[::-1]

# Sort similar users by score
similar_user_score = np.sort(similarity[user_index])[::-1]

# Store unrated recipes (for the user considered)
unrated_recipes = X_train.iloc[user_index][X_train.iloc[user_index].isna()].index 

# Weight ratings of the top n most similar users with their rating and compute the mean for each recipe
mean_recipe_recommendations = (train.iloc[similar_user_index[:n_recommendation]].T * similar_user_score[:n_recommendation]).T.mean(axis=0)

# Filter already rated recipes for user regarded and sort results
best_recipe_recommendations = mean_recipe_recommendations[unrated_recipes].sort_values(ascending=False).to_frame().join(names)

# Create user-id mapping
user_id_mapping = {id:i for i, id in enumerate(train.index)}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-94d6b7604940> in <module>
#       4
#       5 # Compute similarity between all users
# ----> 6 similarity = cosine_similarity(train.values)
#       7
#       8 # Remove self-similarity from similarity-matrix
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1034
#    1035     K = safe_sparse_dot(X_normalized, Y_normalized.T,
# -> 1036                         dense_output=dense_output)
#    1037
#    1038     return K
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     140         return ret
#     141     else:
# --> 142         return np.dot(a, b)
#     143
#     144
#
# KeyboardInterrupt:

# %%
prediction = []
# Iterate over all testset users
for user_id in df_test['u'].unique():
    
    # Sort similar users by index 
    # We previously need to compute the similarity of each user wrt to all others
    similar_user_index = np.argsort(similarity[user_id_mapping[user_id]])[::-1]
    # Sort similar users by score
    similar_user_score = np.sort(similarity[user_id_mapping[user_id]])[::-1]
    
    # Regard only recipes that are present in the test set - there are NaN values
    for recipe_id in df_test[df_test['u']==user_id]['i'].values:

        # Compute predicted score (weighted average of similar user score)
        score = (train.iloc[similar_user_index[:n_recommendation]][recipe_id] * similar_user_score[:n_recommendation]).values.sum() / similar_user_score[:n_recommendation].sum()
        prediction.append([user_id, recipe_id, score])

# %%
# Create prediction DataFrame - predict ratings of the recipes in test sets (for each user)
df_pred = pd.DataFrame(prediction, columns=['u', 'i', 'Prediction']).set_index(['u', 'i'])
df_pred = df_test.set_index(['u', 'i']).join(df_pred)

# %%
# Drop NaN values (observations without ratings for each user)
df_pred = df_pred.dropna()

# %%
# Get labels and predictions
y_true = df_pred['rating'].values
y_pred = df_pred['Prediction'].values

# %%
# Compute RMSE
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_true=y_true, y_pred=y_pred))

# %%
# Create trace
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
trace = go.Bar(x = best_recipe_recommendations.iloc[:n_plot, 0],
               text = best_recipe_recommendations['name'],
               textposition = 'inside',
               textfont = dict(color = '#000000'),
               orientation = 'h',
               y = list(range(1, n_plot+1)),
               marker = dict(color = '#db0000'))
# Create layout
layout = dict(title = 'Ranking Of Top {} Recommended Recipes For A User Based On Similarity: {:.4f} RMSE'.format(n_plot, rmse),
              xaxis = dict(title = 'Recommendation-Rating',
                           range = (4.1, 4.5)),
              yaxis = dict(title = 'Movie'))
# Create plot
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
